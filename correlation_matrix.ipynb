# %%
import process_db
import h5py
import pandas as pd
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns
import random
random.seed(1)

rna_embeddings = np.loadtxt('./output/sce_10xPBMC_rna_skip_referenced_random_right_path_embeddings.txt')
data_library = pd.read_csv('library.txt', sep=" ", header=None)
data_umi = pd.read_csv('umi.txt', sep=" ", header=None)
data_sscore = pd.read_csv('S.score.txt', sep=" ", header=None)
data_G2Mscore = pd.read_csv('G2M.score.txt', sep=" ", header=None)

# %%
df_embeddings = pd.DataFrame(rna_embeddings)

# %%
#result_library = pd.concat([df_embeddings, data_library[0]], axis=1).corr()
#print(result_library)
print(df_embeddings.corrwith(data_umi[0], axis = 0))
print(df_embeddings.corrwith(data_sscore[0], axis = 0))
print(df_embeddings.corrwith(data_G2Mscore[0], axis = 0))
# Out:
# 0     0.011216
# 1    -0.000432
# 2     0.015058
# 3    -0.008760
# 4    -0.007826
#         ...
# 59   -0.015357
# 60   -0.012925
# 61   -0.009911
# 62   -0.027325
# 63    0.002071
# Length: 64, dtype: float64
# 0     0.016231
# 1     0.015087
# 2    -0.067348
# 3     0.031119
# 4     0.049881
#         ...
# 59    0.035157
# 60    0.022088
# 61   -0.045837
# 62   -0.000372
# 63    0.001413
# Length: 64, dtype: float64
# 0     0.033958
# 1    -0.003382
# 2    -0.044102
# 3     0.021278
# 4     0.038706
#         ...
# 59    0.058145
# 60   -0.012655
# 61   -0.042288
# 62   -0.054875
# 63   -0.018994
# Length: 64, dtype: float64

# %%
#result_library = pd.concat([df_embeddings, data_library[0]], axis=1).corr()
#print(result_library)
#print(df_embeddings.corrwith(data_umi[0], axis = 0))
#print(df_embeddings.corrwith(data_sscore[0], axis = 0))
#print(df_embeddings.corrwith(data_G2Mscore[0], axis = 0))
import numpy as np
import seaborn as sns
from matplotlib.colors import ListedColormap
import matplotlib.pyplot as plt
#print(df_embeddings.corrwith(data_umi[0], axis = 0))
data = np.asarray(df_embeddings.corrwith(data_umi[0], axis = 0)).reshape(64,1)
#print(data)
sns.heatmap(data)#,cmap=ListedColormap(['green', 'yellow', 'red']))
plt.show()
data = np.asarray(df_embeddings.corrwith(data_sscore[0], axis = 0)).reshape(64,1)
sns.heatmap(data)#,cmap=ListedColormap(['green', 'yellow', 'red']))
plt.show()
data = np.asarray(df_embeddings.corrwith(data_G2Mscore[0], axis = 0)).reshape(64,1)
sns.heatmap(data)#,cmap=ListedColormap(['green', 'yellow', 'red']))
plt.show()

#sns.heatmap(df_embeddings.corrwith(data_umi[0], axis = 0), annot=True)
#plt.show()
#sns.heatmap(df_embeddings.corrwith(data_sscore[0], axis = 0), annot=True)
#plt.show()
#sns.heatmap(df_embeddings.corrwith(data_G2Mscore[0], axis = 0), annot=True)
#plt.show()

# %%
#result_library = pd.concat([df_embeddings, data_library[0]], axis=1).corr()
#print(result_library)
#print(df_embeddings.corrwith(data_umi[0], axis = 0))
#print(df_embeddings.corrwith(data_sscore[0], axis = 0))
#print(df_embeddings.corrwith(data_G2Mscore[0], axis = 0))
import numpy as np
import seaborn as sns
from matplotlib.colors import ListedColormap
import matplotlib.pyplot as plt
#print(df_embeddings.corrwith(data_umi[0], axis = 0))

data = np.asarray(df_embeddings.corrwith(pd.concat([data_umi[0],data_sscore[0]]), axis = 0)).reshape(64,1)
#print(data)
sns.heatmap(data)#,cmap=ListedColormap(['green', 'yellow', 'red']))
plt.show()
data = np.asarray(df_embeddings.corrwith(pd.concat([data_sscore[0],data_G2Mscore[0]]), axis = 0)).reshape(64,1)
sns.heatmap(data)#,cmap=ListedColormap(['green', 'yellow', 'red']))
plt.show()
#data = np.asarray(df_embeddings.corrwith(data_G2Mscore[0], axis = 0)).reshape(64,1)
#sns.heatmap(data)#,cmap=ListedColormap(['green', 'yellow', 'red']))
#plt.show()
data = np.asarray(df_embeddings.corrwith(pd.concat([data_umi[0],data_G2Mscore[0]]), axis = 0)).reshape(64,1)
sns.heatmap(data)#,cmap=ListedColormap(['green', 'yellow', 'red']))
plt.show()
#sns.heatmap(df_embeddings.corrwith(data_umi[0], axis = 0), annot=True)
#plt.show()
#sns.heatmap(df_embeddings.corrwith(data_sscore[0], axis = 0), annot=True)
#plt.show()
#sns.heatmap(df_embeddings.corrwith(data_G2Mscore[0], axis = 0), annot=True)
#plt.show()

# %%
print(pd.concat([data_umi[0],data_sscore[0],data_G2Mscore[0]]))
data = np.asarray(df_embeddings.corrwith(pd.concat([data_umi[0],data_sscore[0],data_G2Mscore[0]]), axis = 0)).reshape(64,1)
sns.heatmap(data)#,cmap=ListedColormap(['green', 'yellow', 'red']))
plt.show()
# Out:
# 0        111032.000000
# 1        101008.000000
# 2         69928.000000
# 3         58115.000000
# 4         54295.000000
#              ...
# 30300        -0.048853
# 30301        -0.016207
# 30302        -0.056418
# 30303        -0.036106
# 30304        -0.018936
# Name: 0, Length: 90915, dtype: float64

# %%
def corr(df1, df2):
    n = len(df1)
    v1, v2 = df1.values, df2.values
    #print(v1)
    #print(v2)
    sums = np.multiply.outer(v2.sum(0), v1.sum(0))
    stds = np.multiply.outer(v2.std(0), v1.std(0))
    return pd.DataFrame((v2.T.dot(v1) - sums / n) / stds / n,
                        df2.columns, df1.columns)

df_corr_lib=corr(df_embeddings, data_umi[0])
print(df_corr_lib)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [16], in <cell line: 11>()
#       7     stds = np.multiply.outer(v2.std(0), v1.std(0))
#       8     return pd.DataFrame((v2.T.dot(v1) - sums / n) / stds / n,
#       9                         df2.columns, df1.columns)
# ---> 11 df_corr_lib=corr(df_embeddings, data_umi[0])
#      12 print(df_corr_lib)
#
# Input In [16], in corr(df1, df2)
#       6 sums = np.multiply.outer(v2.sum(0), v1.sum(0))
#       7 stds = np.multiply.outer(v2.std(0), v1.std(0))
#       8 return pd.DataFrame((v2.T.dot(v1) - sums / n) / stds / n,
# ----> 9                     df2.columns, df1.columns)
#
# File ~/conda/lib/python3.9/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
# ...

# %%
sns.heatmap(result_library, annot=True)
plt.show()
