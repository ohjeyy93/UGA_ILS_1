# %%
import rpy2.robjects as robjects
from rpy2.robjects import pandas2ri
pandas2ri.activate()

readRDS = robjects.r['readRDS']
df = readRDS('data/snRNA.raw.sparse_referenced.rds')
df = pandas2ri.ri2py(df)
# do something with the dataframe
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/conda/lib/python3.9/site-packages/rpy2/rinterface_lib/openrlib.py:18, in <module>
#      17 try:
# ---> 18     import _rinterface_cffi_api as _rinterface_cffi  # type: ignore
#      19 except ImportError:
#
# ModuleNotFoundError: No module named '_rinterface_cffi_api'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 import rpy2.robjects as robjects
#       2 from rpy2.robjects import pandas2ri
#       3 pandas2ri.activate()
#
# File ~/conda/lib/python3.9/site-packages/rpy2/robjects/__init__.py:15, in <module>
#      13 import types
#      14 import typing
# ---> 15 import rpy2.rinterface as rinterface
#      16 import rpy2.rlike.container as rlc
# ...
